# %%
import warnings
from kurveclient.interaction import autofe_local_source
import pathlib
import datetime
import pandas as pd
pd.options.mode.chained_assignment = None  # None, 'warn' (default), or 'raise'

# %%
help(autofe_local_source)
# Out:
# Help on function autofe_local_source in module kurveclient.interaction:
#
# autofe_local_source(path: Union[str, pathlib.Path], storage_format: Optional[str] = None, parent_node: str = '', label_node: str = '', label_field: str = 'id', label_operation: str = 'count', compute_period: int = 365, label_period: int = 30, cut_date: datetime.datetime = datetime.datetime(2024, 10, 30, 8, 40, 15, 297991), hops_front: int = 1, hops_back: int = 2) -> pandas.core.frame.DataFrame
#     Perform automatic feature engineering on a local
#     data source and return the results.

# %%
# !ls cust_data
# Out:
# cust.csv                           notifications.csv
# notification_interaction_types.csv order_products.csv
# notification_interactions.csv      orders.csv

# %%
# perform automated feature engineering from raw data

# %%
p = pathlib.Path('./cust_data')

# %%
vect1 = autofe_local_source(
    path=p.absolute(),
    storage_format='csv',
    parent_node=f'{p.absolute()}/cust.csv',
    label_node=f'{p.absolute()}/orders.csv',
    label_field='id',
    label_operation='count',
    cut_date=datetime.datetime(2023,9,1)
)
# Out:
# 2024-10-30 08:45:50 [warning  ] no `date_key` set for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interaction_types.csv fmt=csv prefix=nointy>
# 2024-10-30 08:45:50 [warning  ] no `date_key` set for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/cust.csv fmt=csv prefix=cust>
# 2024-10-30 08:45:50 [warning  ] no `date_key` set for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/order_products.csv fmt=csv prefix=orpr>
# 2024-10-30 08:45:50 [info     ] hydrating graph attributes
# 2024-10-30 08:45:50 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 08:45:50 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 08:45:50 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 08:45:50 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 08:45:50 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 08:45:50 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 08:45:50 [info     ] hydrating graph data
# 2024-10-30 08:45:50 [info     ] checking for prefix uniqueness
# 2024-10-30 08:45:50 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interactions.csv fmt=csv prefix=noin>
# 2024-10-30 08:45:50 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interaction_types.csv fmt=csv prefix=nointy>
# 2024-10-30 08:45:50 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notifications.csv fmt=csv prefix=noti>
# 2024-10-30 08:45:50 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/cust.csv fmt=csv prefix=cust>
# 2024-10-30 08:45:50 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/order_products.csv fmt=csv prefix=orpr>
# 2024-10-30 08:45:50 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/orders.csv fmt=csv prefix=orde>
# 2024-10-30 08:45:50 [info     ] depth-first traversal through the graph from source: <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/cust.csv fmt=csv prefix=cust>
# 2024-10-30 08:45:50 [info     ] reducing relation <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/order_products.csv fmt=csv prefix=orpr>
# 2024-10-30 08:45:50 [info     ] performing auto_features on node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/order_products.csv fmt=csv prefix=orpr> with reduce key order_id
# 2024-10-30 08:45:50 [info     ] joining <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/order_products.csv fmt=csv prefix=orpr> to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/orders.csv fmt=csv prefix=orde>
# 2024-10-30 08:45:50 [info     ] reducing relation <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/orders.csv fmt=csv prefix=orde>
# 2024-10-30 08:45:50 [info     ] performing auto_features on node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/orders.csv fmt=csv prefix=orde> with reduce key customer_id
# Percentage of rows removed due to invalid dates: 0.00%
# 2024-10-30 08:45:50 [info     ] computed post-aggregation features for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/orders.csv fmt=csv prefix=orde>
# 2024-10-30 08:45:50 [info     ] merged all ts groupings to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/orders.csv fmt=csv prefix=orde>
# 2024-10-30 08:45:50 [info     ] joining <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/orders.csv fmt=csv prefix=orde> to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/cust.csv fmt=csv prefix=cust>
# 2024-10-30 08:45:50 [info     ] Had label node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/orders.csv fmt=csv prefix=orde>
# 2024-10-30 08:45:50 [info     ] computed labels for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/orders.csv fmt=csv prefix=orde>
# 2024-10-30 08:45:50 [info     ] reducing relation <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interactions.csv fmt=csv prefix=noin>
# 2024-10-30 08:45:50 [info     ] performing auto_features on node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interactions.csv fmt=csv prefix=noin> with reduce key notification_id
# Percentage of rows removed due to invalid dates: 0.00%
# 2024-10-30 08:45:50 [info     ] computed post-aggregation features for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interactions.csv fmt=csv prefix=noin>
# 2024-10-30 08:45:50 [info     ] merged all ts groupings to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interactions.csv fmt=csv prefix=noin>
# 2024-10-30 08:45:50 [info     ] joining <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interactions.csv fmt=csv prefix=noin> to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notifications.csv fmt=csv prefix=noti>
# 2024-10-30 08:45:50 [info     ] reducing relation <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notifications.csv fmt=csv prefix=noti>
# 2024-10-30 08:45:50 [info     ] performing auto_features on node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notifications.csv fmt=csv prefix=noti> with reduce key customer_id
# Percentage of rows removed due to invalid dates: 0.00%
# 2024-10-30 08:45:50 [info     ] computed post-aggregation features for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notifications.csv fmt=csv prefix=noti>
# 2024-10-30 08:45:50 [info     ] merged all ts groupings to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notifications.csv fmt=csv prefix=noti>
# 2024-10-30 08:45:50 [info     ] joining <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notifications.csv fmt=csv prefix=noti> to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/cust.csv fmt=csv prefix=cust>

# %%
# perform automated feature engineering at the notification-level

# %%
vect2 = autofe_local_source(
    path=p.absolute(),
    storage_format='csv',
    parent_node=f'{p.absolute()}/notifications.csv',
    label_node=f'{p.absolute()}/notification_interactions.csv',
    label_field='id',
    label_operation='count',
    cut_date=datetime.datetime(2023,9,1)
)
# Out:
# 2024-10-30 08:45:54 [warning  ] no `date_key` set for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interaction_types.csv fmt=csv prefix=nointy>
# 2024-10-30 08:45:54 [warning  ] no `date_key` set for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/cust.csv fmt=csv prefix=cust>
# 2024-10-30 08:45:54 [warning  ] no `date_key` set for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/order_products.csv fmt=csv prefix=orpr>
# 2024-10-30 08:45:54 [info     ] hydrating graph attributes
# 2024-10-30 08:45:54 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 08:45:54 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 08:45:54 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 08:45:54 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 08:45:54 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 08:45:54 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 08:45:54 [info     ] hydrating graph data
# 2024-10-30 08:45:54 [info     ] checking for prefix uniqueness
# 2024-10-30 08:45:54 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interactions.csv fmt=csv prefix=noin>
# 2024-10-30 08:45:54 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interaction_types.csv fmt=csv prefix=nointy>
# 2024-10-30 08:45:54 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notifications.csv fmt=csv prefix=noti>
# 2024-10-30 08:45:54 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/cust.csv fmt=csv prefix=cust>
# 2024-10-30 08:45:54 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/order_products.csv fmt=csv prefix=orpr>
# 2024-10-30 08:45:54 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/orders.csv fmt=csv prefix=orde>
# 2024-10-30 08:45:54 [info     ] depth-first traversal through the graph from source: <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notifications.csv fmt=csv prefix=noti>
# 2024-10-30 08:45:54 [info     ] reducing relation <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interactions.csv fmt=csv prefix=noin>
# 2024-10-30 08:45:54 [info     ] performing auto_features on node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interactions.csv fmt=csv prefix=noin> with reduce key notification_id
# Percentage of rows removed due to invalid dates: 0.00%
# 2024-10-30 08:45:54 [info     ] computed post-aggregation features for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interactions.csv fmt=csv prefix=noin>
# 2024-10-30 08:45:54 [info     ] merged all ts groupings to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interactions.csv fmt=csv prefix=noin>
# 2024-10-30 08:45:54 [info     ] joining <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interactions.csv fmt=csv prefix=noin> to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notifications.csv fmt=csv prefix=noti>
# 2024-10-30 08:45:54 [info     ] Had label node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interactions.csv fmt=csv prefix=noin>
# 2024-10-30 08:45:54 [info     ] computed labels for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/cust_data/notification_interactions.csv fmt=csv prefix=noin>

# %%
print(vect1.shape)
print(vect2.shape)
# Out:
# (4, 24)
# (17, 18)

# %%
vect1.head()
# Out:
#    cust_id cust_name  orde_customer_id  orde_id_count  orde_customer_id_count  \
# 0        1       wes               1.0            2.0                     2.0
# 1        2      john               2.0            1.0                     1.0
# 2        3      ryan               3.0            1.0                     1.0
# 3        4    tianji               NaN            NaN                     NaN
#
#                 orde_ts_min orde_ts_max  orde_time_since_last_event  \
# 0 2023-05-12 00:00:00+00:00  2023-06-01                   7948800.0
# 1 2023-01-01 00:00:00+00:00  2023-01-01                  20995200.0
# 2 2023-06-01 00:00:00+00:00  2023-06-01                   7948800.0
# 3                       NaT         NaT                         NaN
#
#    orde_30d_num_events  orde_60d_num_events  ...  noti_customer_id  \
# 0                  NaN                  NaN  ...               1.0
# 1                  NaN                  NaN  ...               2.0
# 2                  NaN                  NaN  ...               3.0
# 3                  NaN                  NaN  ...               NaN
#
#    noti_id_count  noti_customer_id_count               noti_ts_min  \
# 0            5.0                     5.0 2023-01-01 00:00:00+00:00
# 1            7.0                     7.0 2022-09-05 00:00:00+00:00
# 2            1.0                     1.0 2023-06-12 00:00:00+00:00
# 3            NaN                     NaN                       NaT
#
#    noti_ts_max  noti_time_since_last_event  noti_30d_num_events  \
# 0   2023-06-23                   6048000.0                  NaN
# 1   2023-05-22                   8812800.0                  NaN
# 2   2023-06-12                   6998400.0                  NaN
# 3          NaT                         NaN                  NaN
#
#   noti_60d_num_events noti_90d_num_events  noti_365d_num_events
# 0                 NaN                 1.0                   5.0
# 1                 NaN                 NaN                   7.0
# 2                 NaN                 1.0                   1.0
# 3                 NaN                 NaN                   NaN
#
# [4 rows x 24 columns]

# %%
vect2.head()
# Out:
#    noti_id  noti_customer_id     noti_ts  cust_id cust_name  \
# 0      101                 1  2022-08-05        1       wes
# 1      102                 1  2023-01-01        1       wes
# 2      103                 1  2023-05-05        1       wes
# 3      104                 1  2023-06-01        1       wes
# 4      105                 1  2023-06-02        1       wes
#
#    noin_notification_id  noin_id_count  noin_notification_id_count  \
# 0                   NaN            NaN                         NaN
# 1                 102.0            3.0                         3.0
# 2                 103.0            3.0                         3.0
# 3                 104.0            2.0                         2.0
# 4                 105.0            2.0                         2.0
#
#    noin_interaction_type_id_count               noin_ts_min noin_ts_max  \
# 0                             NaN                       NaT         NaT
# 1                             3.0 2023-01-01 00:00:00+00:00  2023-01-03
# 2                             3.0 2023-05-05 00:00:00+00:00  2023-05-07
# 3                             2.0 2023-05-10 00:00:00+00:00  2023-05-11
# 4                             2.0 2023-05-11 00:00:00+00:00  2023-05-11
#
#    noin_time_since_last_event  noin_30d_num_events  noin_60d_num_events  \
# 0                         NaN                  NaN                  NaN
# 1                  20822400.0                  NaN                  NaN
# 2                  10108800.0                  NaN                  NaN
# 3                   9763200.0                  NaN                  NaN
# 4                   9763200.0                  NaN                  NaN
#
#    noin_90d_num_events  noin_365d_num_events  noin_notification_id_dupe  \
# 0                  NaN                   NaN                        NaN
# 1                  NaN                   3.0                        NaN
# 2                  NaN                   3.0                        NaN
# 3                  NaN                   2.0                        NaN
# 4                  NaN                   2.0                        NaN
#
#    noin_id_label
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
