# %%
import warnings
from kurveclient.interaction import autofe_local_source
import pathlib
import datetime
import pandas as pd
pd.options.mode.chained_assignment = None  # None, 'warn' (default), or 'raise'
pd.set_option('display.max_columns', 100)

# %%
# download the data

# %%
# !ls ./movie_data.zip
# Out:
# ./movie_data.zip

# %%
#!wget https://github.com/kurveai/kurveclient/raw/refs/heads/main/examples/data/movie_data.zip
#!unzip movie_data.zip

# %%
# perform automated feature engineering on the data
p = pathlib.Path('./movie_data')

# %%
vect1 = autofe_local_source(
    path=p.absolute(),
    storage_format='csv',
    parent_node=f'{p.absolute()}/rental.csv',
    label_node=f'{p.absolute()}/payment.csv',
    label_field='id',
    label_operation='count',
    cut_date=datetime.datetime(2022,3,1),
    hops_front=1,
    hops_back=3
)
# Out:
# 2024-10-30 15:08:03 [info     ] hydrating graph attributes
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 15:08:03 [info     ] hydrating graph data
# 2024-10-30 15:08:03 [info     ] checking for prefix uniqueness
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/address.csv fmt=csv prefix=addr>
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/city.csv fmt=csv prefix=city>
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/country.csv fmt=csv prefix=coun>
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/customer.csv fmt=csv prefix=cust>
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/store.csv fmt=csv prefix=stor>
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/film.csv fmt=csv prefix=film>
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/language.csv fmt=csv prefix=lang>
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/film_actor.csv fmt=csv prefix=fiac>
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/actor.csv fmt=csv prefix=acto>
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/film_category.csv fmt=csv prefix=fica>
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/category.csv fmt=csv prefix=cate>
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/inventory.csv fmt=csv prefix=inve>
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/payment.csv fmt=csv prefix=paym>
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/rental.csv fmt=csv prefix=rent>
# 2024-10-30 15:08:03 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/staff.csv fmt=csv prefix=staf>
# 2024-10-30 15:08:03 [info     ] depth-first traversal through the graph from source: <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/rental.csv fmt=csv prefix=rent>
# 2024-10-30 15:08:03 [info     ] reducing relation <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/payment.csv fmt=csv prefix=paym>
# 2024-10-30 15:08:03 [info     ] performing auto_features on node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/payment.csv fmt=csv prefix=paym> with reduce key rental_id
# 2024-10-30 15:08:03 [info     ] skipped aggregation on paym_payment_date because semantic numerical but physical object
# 2024-10-30 15:08:03 [info     ] skipped aggregation on paym_payment_date because semantic numerical but physical object
# 2024-10-30 15:08:03 [info     ] joining <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/payment.csv fmt=csv prefix=paym> to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/rental.csv fmt=csv prefix=rent>
# 2024-10-30 15:08:03 [info     ] Had label node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/payment.csv fmt=csv prefix=paym>
# 2024-10-30 15:08:03 [info     ] computed labels for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/payment.csv fmt=csv prefix=paym>

# %%
vect1.shape
# Out:
# (16044, 42)

# %%
vect1.head()
# Out:
#    rent_rental_id        rent_rental_date  rent_inventory_id  \
# 0               2  2022-05-25 00:54:33+03               1525
# 1               3  2022-05-25 01:03:39+03               1711
# 2               4  2022-05-25 01:04:41+03               2452
# 3               5  2022-05-25 01:05:21+03               2079
# 4               6  2022-05-25 01:08:07+03               2792
#
#    rent_customer_id        rent_return_date  rent_staff_id  \
# 0               459  2022-05-28 21:40:33+03              1
# 1               408  2022-06-02 00:12:39+03              1
# 2               333  2022-06-03 03:43:41+03              2
# 3               222  2022-06-02 06:33:21+03              1
# 4               549  2022-05-27 03:32:07+03              1
#
#          rent_last_update  staf_staff_id staf_first_name staf_last_name  \
# 0  2022-02-16 05:30:53+03              1            Mike        Hillyer
# 1  2022-02-16 05:30:53+03              1            Mike        Hillyer
# 2  2022-02-16 05:30:53+03              2             Jon       Stephens
# 3  2022-02-16 05:30:53+03              1            Mike        Hillyer
# 4  2022-02-16 05:30:53+03              1            Mike        Hillyer
#
#    staf_address_id                    staf_email  staf_store_id  staf_active  \
# 0                3  Mike.Hillyer@sakilastaff.com              1         True
# 1                3  Mike.Hillyer@sakilastaff.com              1         True
# 2                4  Jon.Stephens@sakilastaff.com              2         True
# 3                3  Mike.Hillyer@sakilastaff.com              1         True
# 4                3  Mike.Hillyer@sakilastaff.com              1         True
#
#   staf_username                             staf_password  \
# 0          Mike  8cb2237d0679ca88db6464eac60da96345513964
# 1          Mike  8cb2237d0679ca88db6464eac60da96345513964
# 2           Jon  8cb2237d0679ca88db6464eac60da96345513964
# 3          Mike  8cb2237d0679ca88db6464eac60da96345513964
# 4          Mike  8cb2237d0679ca88db6464eac60da96345513964
#
#                staf_last_update staf_picture  inve_inventory_id  inve_film_id  \
# 0  2022-05-16 18:13:11.79328+03  binary data               1525           333
# 1  2022-05-16 18:13:11.79328+03  binary data               1711           373
# 2  2022-05-16 18:13:11.79328+03          NaN               2452           535
# 3  2022-05-16 18:13:11.79328+03  binary data               2079           450
# 4  2022-05-16 18:13:11.79328+03  binary data               2792           613
#
#    inve_store_id        inve_last_update  cust_customer_id  cust_store_id  \
# 0              2  2022-02-15 13:09:17+03               459              1
# 1              2  2022-02-15 13:09:17+03               408              1
# 2              1  2022-02-15 13:09:17+03               333              2
# 3              2  2022-02-15 13:09:17+03               222              2
# 4              1  2022-02-15 13:09:17+03               549              1
#
#   cust_first_name cust_last_name                             cust_email  \
# 0           TOMMY        COLLAZO       TOMMY.COLLAZO@sakilacustomer.org
# 1          MANUEL        MURRELL      MANUEL.MURRELL@sakilacustomer.org
# 2          ANDREW          PURDY        ANDREW.PURDY@sakilacustomer.org
# 3         DELORES         HANSEN      DELORES.HANSEN@sakilacustomer.org
# 4          NELSON    CHRISTENSON  NELSON.CHRISTENSON@sakilacustomer.org
#
#    cust_address_id  cust_activebool cust_create_date        cust_last_update  \
# 0              464             True       2022-02-14  2022-02-15 12:57:20+03
# 1              413             True       2022-02-14  2022-02-15 12:57:20+03
# 2              338             True       2022-02-14  2022-02-15 12:57:20+03
# 3              226             True       2022-02-14  2022-02-15 12:57:20+03
# 4              555             True       2022-02-14  2022-02-15 12:57:20+03
#
#    cust_active  paym_rental_id  paym_payment_id_count  paym_customer_id_count  \
# 0            1             2.0                    1.0                     1.0
# 1            1             NaN                    NaN                     NaN
# 2            1             NaN                    NaN                     NaN
# 3            1             NaN                    NaN                     NaN
# 4            1             NaN                    NaN                     NaN
#
#    paym_staff_id_count  paym_rental_id_count  paym_amount_median  \
# 0                  1.0                   1.0                2.99
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#    paym_amount_mean  paym_amount_sum  paym_amount_min  paym_amount_max
# 0              2.99             2.99             2.99             2.99
# 1               NaN              NaN              NaN              NaN
# 2               NaN              NaN              NaN              NaN
# 3               NaN              NaN              NaN              NaN
# 4               NaN              NaN              NaN              NaN

# %%
vect2 = autofe_local_source(
    path=p.absolute(),
    storage_format='csv',
    parent_node=f'{p.absolute()}/customer.csv',
    label_node=f'{p.absolute()}/rental.csv',
    label_field='id',
    label_operation='count',
    cut_date=datetime.datetime(2022,3,1),
hops_front=1,
hops_back=3
)
# Out:
# 2024-10-30 13:25:17 [info     ] hydrating graph attributes
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating attributes for DynamicNode
# 2024-10-30 13:25:17 [info     ] hydrating graph data
# 2024-10-30 13:25:17 [info     ] checking for prefix uniqueness
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/address.csv fmt=csv prefix=addr>
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/store.csv fmt=csv prefix=stor>
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/city.csv fmt=csv prefix=city>
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/country.csv fmt=csv prefix=coun>
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/customer.csv fmt=csv prefix=cust>
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/film.csv fmt=csv prefix=film>
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/language.csv fmt=csv prefix=lang>
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/film_actor.csv fmt=csv prefix=fiac>
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/actor.csv fmt=csv prefix=acto>
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/film_category.csv fmt=csv prefix=fica>
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/category.csv fmt=csv prefix=cate>
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/inventory.csv fmt=csv prefix=inve>
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/payment.csv fmt=csv prefix=paym>
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/staff.csv fmt=csv prefix=staf>
# 2024-10-30 13:25:17 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/rental.csv fmt=csv prefix=rent>
# 2024-10-30 13:25:17 [info     ] depth-first traversal through the graph from source: <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/customer.csv fmt=csv prefix=cust>
# 2024-10-30 13:25:17 [info     ] reducing relation <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/rental.csv fmt=csv prefix=rent>
# 2024-10-30 13:25:17 [info     ] performing auto_features on node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/rental.csv fmt=csv prefix=rent> with reduce key customer_id
# Percentage of rows removed due to invalid dates: 0.00%
# 2024-10-30 13:25:17 [info     ] skipped aggregation on rent_return_date because semantic numerical but physical object
# 2024-10-30 13:25:17 [info     ] skipped aggregation on rent_return_date because semantic numerical but physical object
# 2024-10-30 13:25:17 [info     ] skipped aggregation on rent_last_update because semantic numerical but physical object
# 2024-10-30 13:25:17 [info     ] skipped aggregation on rent_last_update because semantic numerical but physical object
# 2024-10-30 13:25:17 [info     ] computed post-aggregation features for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/rental.csv fmt=csv prefix=rent>
# 2024-10-30 13:25:17 [info     ] merged all ts groupings to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/rental.csv fmt=csv prefix=rent>
# 2024-10-30 13:25:17 [info     ] joining <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/rental.csv fmt=csv prefix=rent> to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/customer.csv fmt=csv prefix=cust>
# 2024-10-30 13:25:17 [info     ] Had label node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/rental.csv fmt=csv prefix=rent>
# 2024-10-30 13:25:17 [info     ] computed labels for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/rental.csv fmt=csv prefix=rent>
# 2024-10-30 13:25:17 [info     ] reducing relation <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/payment.csv fmt=csv prefix=paym>
# 2024-10-30 13:25:17 [info     ] performing auto_features on node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/payment.csv fmt=csv prefix=paym> with reduce key customer_id
# Percentage of rows removed due to invalid dates: 0.00%
# 2024-10-30 13:25:17 [info     ] computed post-aggregation features for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/payment.csv fmt=csv prefix=paym>
# 2024-10-30 13:25:17 [info     ] merged all ts groupings to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/payment.csv fmt=csv prefix=paym>
# 2024-10-30 13:25:17 [info     ] joining <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/payment.csv fmt=csv prefix=paym> to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/kurveai/kurveclient/examples/movie_data/customer.csv fmt=csv prefix=cust>

# %%
vect2.columns
# Out:
# Index(['cust_customer_id', 'cust_store_id', 'cust_first_name',
#        'cust_last_name', 'cust_email', 'cust_address_id', 'cust_activebool',
#        'cust_create_date', 'cust_last_update', 'cust_active', 'stor_store_id',
#        'stor_manager_staff_id', 'stor_address_id', 'stor_last_update',
#        'rent_customer_id', 'rent_rental_id_count', 'rent_rental_date_min',
#        'rent_rental_date_max', 'rent_inventory_id_count',
#        'rent_customer_id_count', 'rent_staff_id_count',
#        'rent_time_since_last_event', 'rent_30d_num_events',
#        'rent_60d_num_events', 'rent_90d_num_events', 'rent_365d_num_events',
#        'paym_customer_id', 'paym_payment_id_count', 'paym_customer_id_count',
#        'paym_staff_id_count', 'paym_rental_id_count', 'paym_amount_median',
#        'paym_amount_mean', 'paym_amount_sum', 'paym_amount_min',
#        'paym_amount_max', 'paym_payment_date_min', 'paym_payment_date_max',
#        'paym_time_since_last_event', 'paym_30d_num_events',
#        'paym_60d_num_events', 'paym_90d_num_events', 'paym_365d_num_events'],
#       dtype='object')
